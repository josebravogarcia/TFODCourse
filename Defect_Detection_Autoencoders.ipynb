# %% [markdown]
# <a href="https://colab.research.google.com/github/josebravogarcia/TFODCourse/blob/main/Defect_Detection_Autoencoders.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
PATH_SCRIPT = 'drive/MyDrive/GOOGLE_COLAB/Autoencoder/'
# !cd {PATH_SCRIPT}

# %%
command = "python drive/MyDrive/GOOGLE_COLAB/Autoencoder/train.py --name drive/MyDrive/GOOGLE_COLAB/Autoencoder/R5_C5 --loss ssim_loss --im_resize 266 --patch_size 256 --z_dim 500 --do_aug --p_rotate 0. --p_horizonal_flip 0. --p_vertical_flip 0."
# !{command}
# Out:
# Augmenting 201021_193826_0000000350_&icapbk[000].bmp ...
# Augmenting 201021_194057_0000000378_&icapbk[000].bmp ...
# Augmenting 201021_194304_0000000401_&icapbk[000].bmp ...
# Augmenting 201021_194349_0000000409_&icapbk[000].bmp ...
# Augmenting 201021_194551_0000000430_&icapbk[000].bmp ...
# Augmenting 201021_194905_0000000462_&icapbk[000].bmp ...
# Augmenting 201021_195445_0000000499_&icapbk[000].bmp ...
# Augmenting 201021_200556_0000000564_&icapbk[000].bmp ...
# Augmenting 201021_200855_0000000596_&icapbk[000].bmp ...
# Augmenting 201021_201705_0000000661_&icapbk[000].bmp ...
# Augmenting 201021_202847_0000000708_&icapbk[000].bmp ...
# Augmenting 201021_203307_0000000754_&icapbk[000].bmp ...
# Augmenting 201021_204923_0000000888_&icapbk[000].bmp ...
# Augmenting 201021_205637_0000000958_&icapbk[000].bmp ...
# Augmenting 201021_210058_0000001001_&icapbk[000].bmp ...
# Augmenting 201021_210410_0000001031_&icapbk[000].bmp ...
# ...

# %%
command = "python drive/MyDrive/GOOGLE_COLAB/Autoencoder/test.py --name drive/MyDrive/GOOGLE_COLAB/Autoencoder/R5_C5 --loss ssim_loss --im_resize 266 --patch_size 256 --z_dim 500"
# !{command}
# Out:
# 2022-02-27 03:52:26.783080: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# load latest weight file:  49
# ssim_threshold: 0.767904, l1_threshold: 0.118954
# step1
# step2
# step4
# getting results
# getting result:
# ./drive/MyDrive/GOOGLE_COLAB/Autoencoder/R5_C5/test/190917_201537_0000000004_&icapbk[000].bmp
# saving result in:  ./drive/MyDrive/GOOGLE_COLAB/Autoencoder/R5_C5/test/190917_201537_0000000004_&icapbk[000]
# ./drive/MyDrive/GOOGLE_COLAB/Autoencoder/R5_C5/test/190917_201514_0000000003_&icapbk[000].bmp
# saving result in:  ./drive/MyDrive/GOOGLE_COLAB/Autoencoder/R5_C5/test/190917_201514_0000000003_&icapbk[000]
# ./drive/MyDrive/GOOGLE_COLAB/Autoencoder/R5_C5/test/190917_201558_0000000005_&icapbk[000].bmp
# saving result in:  ./drive/MyDrive/GOOGLE_COLAB/Autoencoder/R5_C5/test/190917_201558_0000000005_&icapbk[000]
# ...
